# %% [markdown]
# # Asymflation\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom asymflation import AsymflationCalculator\n

# %%
df = pd.read_csv("asymflation_dataset.csv")\ndf.head()\n

# %%
calc = AsymflationCalculator()\nresult = calc.calculate_asymflation(df)\nresult.head()\n

# %%
result["asymflation_index"].describe()\n

# %%
result.groupby("asymflation_band").size()\n

# %%
result["asymflation_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Asymflation` index is now ready for stress testing.
